# %%
#import packages 📦 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image 
import skimage.io
import skimage.transform
from PIL import Image
import numpy as np
import seaborn as sns
import math
import copy
import tensorflow as tf
# %matplotlib inline

# %%
#import more packages 📦 
import keras.backend as K
from keras import optimizers
from keras_vggface import utils
from keras_vggface.vggface import VGGFace
from keras.preprocessing.image import ImageDataGenerator
from keras_vggface.utils import decode_predictions
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Flatten, Dropout, Activation, Lambda, Permute, Reshape, BatchNormalization
from keras.layers import Convolution2D, ZeroPadding2D, MaxPooling2D
from keras.models import Sequential
from sklearn.metrics import confusion_matrix

# %%
K.clear_session()

# %%
K.set_image_data_format( 'channels_last' ) 
# nrow=180
# ncol=320
nrow = 224
ncol=224

# %%
#load VGG Face
vggface = VGGFace(model='vgg16')

# %%
#custom parameters
# 3 Names, 3 classes
nb_class = 17
hidden_dim = 512

vgg_notop = VGGFace(include_top=False, input_shape=(nrow, ncol, 3))
for layer in vgg_notop.layers:
    layer.trainable = False

last_layer = vgg_notop.get_layer('pool5').output

x = Flatten(name='flatten')(last_layer)
x = Dense(hidden_dim, activation='relu', name='fc6')(x)
x = Dense(hidden_dim, activation='relu', name='fc7')(x)
out = Dense(nb_class, activation='softmax', name='fc8')(x)

custom_vgg_model = Model(vgg_notop.input, out)
custom_vgg_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1_1 (Conv2D)            (None, 224, 224, 64)      1792
#
#  conv1_2 (Conv2D)            (None, 224, 224, 64)      36928
#
#  pool1 (MaxPooling2D)        (None, 112, 112, 64)      0
#
#  conv2_1 (Conv2D)            (None, 112, 112, 128)     73856
#
#  conv2_2 (Conv2D)            (None, 112, 112, 128)     147584
#
#  pool2 (MaxPooling2D)        (None, 56, 56, 128)       0
#
#  conv3_1 (Conv2D)            (None, 56, 56, 256)       295168
#
#  conv3_2 (Conv2D)            (None, 56, 56, 256)       590080
#
#  conv3_3 (Conv2D)            (None, 56, 56, 256)       590080
#
#  pool3 (MaxPooling2D)        (None, 28, 28, 256)       0
#
#  conv4_1 (Conv2D)            (None, 28, 28, 512)       1180160
#
#  conv4_2 (Conv2D)            (None, 28, 28, 512)       2359808
#
#  conv4_3 (Conv2D)            (None, 28, 28, 512)       2359808
#
#  pool4 (MaxPooling2D)        (None, 14, 14, 512)       0
#
#  conv5_1 (Conv2D)            (None, 14, 14, 512)       2359808
#
#  conv5_2 (Conv2D)            (None, 14, 14, 512)       2359808
#
#  conv5_3 (Conv2D)            (None, 14, 14, 512)       2359808
#
#  pool5 (MaxPooling2D)        (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc6 (Dense)                 (None, 512)               12845568
#
#  fc7 (Dense)                 (None, 512)               262656
#
#  fc8 (Dense)                 (None, 17)                8721
#
# =================================================================
# Total params: 27,831,633
# Trainable params: 13,116,945
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#training data set
batch_size = 8

train_data_dir = '../converging_models/masked_dataset/train/'
train_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   )
train_generator = train_datagen.flow_from_directory(
                        train_data_dir,
                        target_size=(nrow,ncol),
                        batch_size=batch_size,
                        class_mode='sparse')
# Out:
# Found 1343 images belonging to 17 classes.

# %%
#test data set
test_data_dir = '../converging_models/masked_dataset/test/'
test_datagen = ImageDataGenerator(rescale=1./255,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                 )
test_generator = test_datagen.flow_from_directory(
                        test_data_dir,
                        target_size=(nrow,ncol),
                        batch_size=batch_size, 
                        shuffle = False,
                        class_mode='sparse')
# Out:
# Found 337 images belonging to 17 classes.

# %%
#display image function
def disp_image(im):
    if (len(im.shape) == 2):
        # Gray scale image
        plt.imshow(im, cmap='gray')    
    else:
        # Color image.  
        im1 = (im-np.min(im))/(np.max(im)-np.min(im))*255
        im1 = im1.astype(np.uint8)
        plt.imshow(im1)    
        
    # Remove axis ticks
    plt.xticks([])
    plt.yticks([])

# %%
names = ['Angelina_Jolie', 'Brad_Pitt', 'Denzel_Washington', 'Hugh_Jackman', 'Jennifer_Lawrence', 'Johnny_Depp', 'Kate_Winslet', 'Leonardo_DiCaprio', 'Megan_Fox', 'Natalie_Portman', 'Nicole_Kidman', 'Robert_Downey_Jr', 'Sandra_Bullock', 'Scarlett_Johansson', 'Tom_Cruise','Tom_Hanks', 'Will_Smith']


batch_shape = (batch_size,custom_vgg_model.input_shape[1] , 
               custom_vgg_model.input_shape[2], 
               custom_vgg_model.input_shape[3])
X = np.zeros(batch_shape)
y = np.zeros(batch_size)

X,y = train_generator.next()
nplot = 4        
for i in range(nplot):    
    plt.subplot(2,int(nplot/2),i+1)
    disp_image(X[i,:,:,:])
    title = (names[int(y[i])])
    plt.title(title)

# %%
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath='./checkpoints/unmasked/',
                                                 save_weights_only=True,
                                                 save_best_only=True,
                                                 monitor= 'val_accuracy',
                                                 verbose=1)

# %%
#train the model
custom_vgg_model.compile(loss='sparse_categorical_crossentropy',
                         optimizer=optimizers.SGD(learning_rate=1e-4, momentum=0.9),
                         metrics=['accuracy'])

# %%
custom_vgg_model.load_weights('mask_face_model.h5')

# %%
steps_per_epoch =  train_generator.n // batch_size
validation_steps =  test_generator.n // batch_size

print(steps_per_epoch)
print(validation_steps)

nepochs = 40

history = custom_vgg_model.fit_generator(
    train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs=nepochs,
    validation_data=test_generator,
    callbacks=[cp_callback],
    validation_steps=validation_steps)
# Out:
# 167
# 42
# Epoch 1/40
# C:\Users\chris\AppData\Local\Temp\ipykernel_11096\117370444.py:9: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = custom_vgg_model.fit_generator(
# 167/167 [==============================] - ETA: 0s - loss: 2.8336 - accuracy: 0.0727
# Epoch 1: val_accuracy improved from -inf to 0.06250, saving model to ./checkpoints/unmasked\
# 167/167 [==============================] - 24s 118ms/step - loss: 2.8336 - accuracy: 0.0727 - val_loss: 2.8343 - val_accuracy: 0.0625
# Epoch 2/40
# 167/167 [==============================] - ETA: 0s - loss: 2.8307 - accuracy: 0.0861
# Epoch 2: val_accuracy did not improve from 0.06250
# 167/167 [==============================] - 16s 96ms/step - loss: 2.8307 - accuracy: 0.0861 - val_loss: 2.8317 - val_accuracy: 0.0625
# Epoch 3/40
# 167/167 [==============================] - ETA: 0s - loss: 2.8264 - accuracy: 0.0906
# Epoch 3: val_accuracy improved from 0.06250 to 0.10119, saving model to ./checkpoints/unmasked\
# 167/167 [==============================] - 18s 108ms/step - loss: 2.8264 - accuracy: 0.0906 - val_loss: 2.8283 - val_accuracy: 0.1012
# Epoch 4/40
# 167/167 [==============================] - ETA: 0s - loss: 2.8205 - accuracy: 0.1086
# Epoch 4: val_accuracy did not improve from 0.10119
# 167/167 [==============================] - 16s 97ms/step - loss: 2.8205 - accuracy: 0.1086 - val_loss: 2.8249 - val_accuracy: 0.1012
# Epoch 5/40
# 167/167 [==============================] - ETA: 0s - loss: 2.8174 - accuracy: 0.1154
# Epoch 5: val_accuracy improved from 0.10119 to 0.10714, saving model to ./checkpoints/unmasked\
# 167/167 [==============================] - 18s 105ms/step - loss: 2.8174 - accuracy: 0.1154 - val_loss: 2.8209 - val_accuracy: 0.1071
# Epoch 6/40
# 167/167 [==============================] - ETA: 0s - loss: 2.8122 - accuracy: 0.1356
# Epoch 6: val_accuracy did not improve from 0.10714
# 167/167 [==============================] - 16s 96ms/step - loss: 2.8122 - accuracy: 0.1356 - val_loss: 2.8203 - val_accuracy: 0.1012
# Epoch 7/40
# 167/167 [==============================] - ETA: 0s - loss: 2.8067 - accuracy: 0.1566
# Epoch 7: val_accuracy improved from 0.10714 to 0.12500, saving model to ./checkpoints/unmasked\
# 167/167 [==============================] - 18s 108ms/step - loss: 2.8067 - accuracy: 0.1566 - val_loss: 2.8141 - val_accuracy: 0.1250
# Epoch 8/40
# 167/167 [==============================] - ETA: 0s - loss: 2.8018 - accuracy: 0.1625
# Epoch 8: val_accuracy improved from 0.12500 to 0.15179, saving model to ./checkpoints/unmasked\
# 167/167 [==============================] - 18s 108ms/step - loss: 2.8018 - accuracy: 0.1625 - val_loss: 2.8136 - val_accuracy: 0.1518
# Epoch 9/40
# 167/167 [==============================] - ETA: 0s - loss: 2.7959 - accuracy: 0.1895
# Epoch 9: val_accuracy did not improve from 0.15179
# 167/167 [==============================] - 16s 96ms/step - loss: 2.7959 - accuracy: 0.1895 - val_loss: 2.8077 - val_accuracy: 0.1339
# Epoch 10/40
# 167/167 [==============================] - ETA: 0s - loss: 2.7895 - accuracy: 0.2022
# Epoch 10: val_accuracy improved from 0.15179 to 0.16369, saving model to ./checkpoints/unmasked\
# 167/167 [==============================] - 18s 111ms/step - loss: 2.7895 - accuracy: 0.2022 - val_loss: 2.8023 - val_accuracy: 0.1637
# Epoch 11/40
# 167/167 [==============================] - ETA: 0s - loss: 2.7829 - accuracy: 0.2172
# Epoch 11: val_accuracy did not improve from 0.16369
# 167/167 [==============================] - 16s 97ms/step - loss: 2.7829 - accuracy: 0.2172 - val_loss: 2.7996 - val_accuracy: 0.1577
# Epoch 12/40
# 167/167 [==============================] - ETA: 0s - loss: 2.7758 - accuracy: 0.2375
# Epoch 12: val_accuracy improved from 0.16369 to 0.17857, saving model to ./checkpoints/unmasked\
# 167/167 [==============================] - 18s 109ms/step - loss: 2.7758 - accuracy: 0.2375 - val_loss: 2.7946 - val_accuracy: 0.1786
# Epoch 13/40
# 167/167 [==============================] - ETA: 0s - loss: 2.7694 - accuracy: 0.2434
# Epoch 13: val_accuracy improved from 0.17857 to 0.19940, saving model to ./checkpoints/unmasked\
# 167/167 [==============================] - 18s 107ms/step - loss: 2.7694 - accuracy: 0.2434 - val_loss: 2.7876 - val_accuracy: 0.1994
# Epoch 14/40
# 167/167 [==============================] - ETA: 0s - loss: 2.7604 - accuracy: 0.2539
# Epoch 14: val_accuracy did not improve from 0.19940
# 167/167 [==============================] - 16s 96ms/step - loss: 2.7604 - accuracy: 0.2539 - val_loss: 2.7812 - val_accuracy: 0.1786
# Epoch 15/40
# 167/167 [==============================] - ETA: 0s - loss: 2.7533 - accuracy: 0.2906
# Epoch 15: val_accuracy improved from 0.19940 to 0.20833, saving model to ./checkpoints/unmasked\
# 167/167 [==============================] - 18s 109ms/step - loss: 2.7533 - accuracy: 0.2906 - val_loss: 2.7776 - val_accuracy: 0.2083
# Epoch 16/40
# 167/167 [==============================] - ETA: 0s - loss: 2.7447 - accuracy: 0.2861
# Epoch 16: val_accuracy did not improve from 0.20833
# 167/167 [==============================] - 16s 97ms/step - loss: 2.7447 - accuracy: 0.2861 - val_loss: 2.7721 - val_accuracy: 0.1935
# Epoch 17/40
# 167/167 [==============================] - ETA: 0s - loss: 2.7362 - accuracy: 0.3034
# Epoch 17: val_accuracy did not improve from 0.20833
# 167/167 [==============================] - 16s 94ms/step - loss: 2.7362 - accuracy: 0.3034 - val_loss: 2.7667 - val_accuracy: 0.1935
# Epoch 18/40
# 167/167 [==============================] - ETA: 0s - loss: 2.7246 - accuracy: 0.3243
# Epoch 18: val_accuracy improved from 0.20833 to 0.22024, saving model to ./checkpoints/unmasked\
# 167/167 [==============================] - 18s 107ms/step - loss: 2.7246 - accuracy: 0.3243 - val_loss: 2.7567 - val_accuracy: 0.2202
# Epoch 19/40
# 167/167 [==============================] - ETA: 0s - loss: 2.7142 - accuracy: 0.3348
# Epoch 19: val_accuracy did not improve from 0.22024
# 167/167 [==============================] - 17s 104ms/step - loss: 2.7142 - accuracy: 0.3348 - val_loss: 2.7473 - val_accuracy: 0.2054
# Epoch 20/40
# 167/167 [==============================] - ETA: 0s - loss: 2.7035 - accuracy: 0.3371
# Epoch 20: val_accuracy improved from 0.22024 to 0.22917, saving model to ./checkpoints/unmasked\
# 167/167 [==============================] - 18s 109ms/step - loss: 2.7035 - accuracy: 0.3371 - val_loss: 2.7374 - val_accuracy: 0.2292
# Epoch 21/40
# 167/167 [==============================] - ETA: 0s - loss: 2.6909 - accuracy: 0.3573
# Epoch 21: val_accuracy did not improve from 0.22917
# 167/167 [==============================] - 16s 98ms/step - loss: 2.6909 - accuracy: 0.3573 - val_loss: 2.7327 - val_accuracy: 0.2292
# Epoch 22/40
# 167/167 [==============================] - ETA: 0s - loss: 2.6781 - accuracy: 0.3655
# Epoch 22: val_accuracy improved from 0.22917 to 0.23214, saving model to ./checkpoints/unmasked\
# 167/167 [==============================] - 19s 111ms/step - loss: 2.6781 - accuracy: 0.3655 - val_loss: 2.7231 - val_accuracy: 0.2321
# Epoch 23/40
# 167/167 [==============================] - ETA: 0s - loss: 2.6647 - accuracy: 0.3775
# Epoch 23: val_accuracy improved from 0.23214 to 0.25298, saving model to ./checkpoints/unmasked\
# 167/167 [==============================] - 19s 112ms/step - loss: 2.6647 - accuracy: 0.3775 - val_loss: 2.7098 - val_accuracy: 0.2530
# Epoch 24/40
# 167/167 [==============================] - ETA: 0s - loss: 2.6536 - accuracy: 0.3768
# Epoch 24: val_accuracy improved from 0.25298 to 0.25595, saving model to ./checkpoints/unmasked\
# 167/167 [==============================] - 18s 110ms/step - loss: 2.6536 - accuracy: 0.3768 - val_loss: 2.7015 - val_accuracy: 0.2560
# Epoch 25/40
# 167/167 [==============================] - ETA: 0s - loss: 2.6370 - accuracy: 0.3925
# Epoch 25: val_accuracy improved from 0.25595 to 0.27976, saving model to ./checkpoints/unmasked\
# 167/167 [==============================] - 18s 108ms/step - loss: 2.6370 - accuracy: 0.3925 - val_loss: 2.6942 - val_accuracy: 0.2798
# Epoch 26/40
# 167/167 [==============================] - ETA: 0s - loss: 2.6234 - accuracy: 0.3903
# Epoch 26: val_accuracy did not improve from 0.27976
# 167/167 [==============================] - 17s 99ms/step - loss: 2.6234 - accuracy: 0.3903 - val_loss: 2.6864 - val_accuracy: 0.2589
# Epoch 27/40
# 167/167 [==============================] - ETA: 0s - loss: 2.6076 - accuracy: 0.4007
# Epoch 27: val_accuracy did not improve from 0.27976
# 167/167 [==============================] - 16s 96ms/step - loss: 2.6076 - accuracy: 0.4007 - val_loss: 2.6686 - val_accuracy: 0.2738
# Epoch 28/40
#  16/167 [=>............................] - ETA: 11s - loss: 2.6027 - accuracy: 0.3438
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [13], line 9
#       5 print(validation_steps)
#       7 nepochs = 40
# ----> 9 history = custom_vgg_model.fit_generator(
#      10     train_generator,
#      11     steps_per_epoch=steps_per_epoch,
#      12     epochs=nepochs,
#      13     validation_data=test_generator,
#      14     callbacks=[cp_callback],
#      15     validation_steps=validation_steps)
#
# File c:\Users\chris\miniconda3\envs\tflabs\lib\site-packages\keras\engine\training.py:2507, in Model.fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2495 """Fits the model on data yielded batch-by-batch by a Python generator.
#    2496
#    2497 DEPRECATED:
#    2498   `Model.fit` now supports generators, so there is no longer any need to
#    2499   use this endpoint.
#    2500 """
#    2501 warnings.warn(
#    2502     "`Model.fit_generator` is deprecated and "
#    2503     "will be removed in a future version. "
#    2504     "Please use `Model.fit`, which supports generators.",
#    2505     stacklevel=2,
#    2506 )
# -> 2507 return self.fit(
#    2508     generator,
#    2509     steps_per_epoch=steps_per_epoch,
#    2510     epochs=epochs,
#    2511     verbose=verbose,
#    2512     callbacks=callbacks,
#    2513     validation_data=validation_data,
#    2514     validation_steps=validation_steps,
#    2515     validation_freq=validation_freq,
#    2516     class_weight=class_weight,
#    2517     max_queue_size=max_queue_size,
#    2518     workers=workers,
#    2519     use_multiprocessing=use_multiprocessing,
#    2520     shuffle=shuffle,
#    2521     initial_epoch=initial_epoch,
#    2522 )
#
# File c:\Users\chris\miniconda3\envs\tflabs\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\envs\tflabs\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File c:\Users\chris\miniconda3\envs\tflabs\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\envs\tflabs\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\chris\miniconda3\envs\tflabs\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File c:\Users\chris\miniconda3\envs\tflabs\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\chris\miniconda3\envs\tflabs\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\chris\miniconda3\envs\tflabs\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\chris\miniconda3\envs\tflabs\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
custom_vgg_model.save('mask_face_model.h5')

# %%
names = [
        'Angelina_Jolie', 'Brad_Pitt', 'Denzel_Washington', 'Hugh_Jackman', 'Jennifer_Lawrence', 'Johnny_Depp', 'Kate_Winslet', 
        'Leonardo_DiCaprio', 'Megan_Fox', 'Natalie_Portman', 'Nicole_Kidman', 'Robert_Downey_Jr', 'Sandra_Bullock', 'Scarlett_Johansson', 
        'Tom_Cruise','Tom_Hanks', 'Will_Smith'
        ]

#Confusion Matrix 
plt.figure(figsize=(15, 5))

#Predict test images
Y_pred = custom_vgg_model.predict(test_generator)

#Get corresponding predicted label
y_pred = np.argmax(Y_pred, axis=1)

cf = confusion_matrix(test_generator.classes, y_pred)

df_cm = pd.DataFrame(cf, index=names, columns=names)

sns.heatmap(df_cm, annot= True,fmt="d",cmap="YlGnBu")
plt.ylabel("Predicted")
plt.xlabel("Actual")
plt.title("Confusion matrix\n")
plt.show()

#Define functions to plot accuracy and loss
def plotAccuracy(history):

    try:
        plt.plot(history.history['accuracy'])
        plt.plot(history.history['val_accuracy'])
    except KeyError:
        plt.plot(history.history['acc'])
        plt.plot(history.history['val_acc'])
    plt.title('Accuracy vs. epochs')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Training', 'Validation'], loc='lower right')
    plt.show() 
    
def plotLoss(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Loss vs. epochs')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Training', 'Validation'], loc='upper right')
    plt.show() 

#Run this cell to plot the new loss vs epoch graph
plotAccuracy(history)
plotLoss(history)

# %%
import face_recognition
import cv2
import numpy as np
from tensorflow.keras.preprocessing import image
#grab preprocess from pre-trained model
from tensorflow.keras.applications.vgg19 import preprocess_input

# image1 = image.load_img("./data/Validation_long/female/113241.jpg.jpg", target_size = (180, 320))
image1 = image.load_img("../Dataset/Validation/Johnny_Depp_011_cloth.jpg", target_size = (nrow, ncol))


transformedImage = image.img_to_array(image1)
transformedImage = np.expand_dims(transformedImage, axis = 0)
transformedImage = utils.preprocess_input(transformedImage, version=1)

prediction = custom_vgg_model.predict(transformedImage)
print(prediction)
print(names[np.argmax(prediction, axis=1)[0]])

# %%
video_capture = cv2.VideoCapture("../Dataset/Video1.mp4")



# Initialize some variables
face_locations = []
face_encodings = []
face_names = []
process_this_frame = True
predictionLabel = ''

while True:
    ret, frame = video_capture.read()

    if process_this_frame:
        small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)
        rgb_small_frame = small_frame[:, :, ::-1]
        face_locations = face_recognition.face_locations(rgb_small_frame)

        new_frame = cv2.resize(frame, (180,320))
        x = image.img_to_array(new_frame)
        x = np.expand_dims(x, axis=0)
        x = utils.preprocess_input(x, version=1) # or version=2
        prediction = custom_vgg_model.predict(x)
        predictionLabel = names[np.argmax(prediction, axis=1)[0]]

        ###

        

    #process_this_frame = not process_this_frame


    for (top, right, bottom, left) in face_locations:
        top *= 4
        right *= 4
        bottom *= 4
        left *= 4

        cv2.rectangle(frame, (left - 10, top - 50), (right + 10, bottom + 50), (0, 0, 255), 2)
        cv2.rectangle(frame, (left-11, bottom + 50), (right + 11, bottom + 75), (0, 0, 255), cv2.FILLED)
        font = cv2.FONT_HERSHEY_DUPLEX
        cv2.putText(frame, predictionLabel, (left - 6, bottom + 65), font, 0.5, (255, 255, 255), 1)

    cv2.imshow('Video', frame)

    # Hit 'q' on the keyboard to quit!
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video_capture.release()
cv2.destroyAllWindows()

# %%
name=names[np.argmax(Y_pred[0])]
print(name)
