# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import cv2
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns
import math

# %%
# Input data files are available in the read only '/input/' directory
# images = []
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         images = np.append(images, cv2.imread(os.path.join(dirname,filename)))
#         print(os.path.join(dirname, filename))

# %%
dirname = '../input/maskedunmaskeddataset/IN_YOUR_FACE_DATASET'
class_count = 2
ds_size = 1800
img_height = 180
img_width = 180

train_ds = tf.keras.utils.image_dataset_from_directory(
    dirname, 
    validation_split=0.2,
    subset='training',
    seed=123,
    image_size=(img_height, img_width))

test_ds = tf.keras.utils.image_dataset_from_directory(
    dirname,
    validation_split=0.2,
    subset='validation',
    seed=123,
    image_size=(img_height, img_width))

class_names = train_ds.class_names
print(test_ds.class_names)
# Out:
# Found 3380 files belonging to 2 classes.
# Using 2704 files for training.
# 2022-11-16 23:53:46.328199: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Found 3380 files belonging to 2 classes.
# Using 676 files for validation.
# ['MASKED_CELEBRITIES', 'UNMASKED_CELEBRITIES']

# %%
class_names = ['masked', 'unmasked']

plt.figure(figsize=(10, 10))
for image, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
# Out:
# 2022-11-16 23:53:46.716756: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %%
# for image, labels in train_ds.take(1):
#     for i in range(2):
#         print(f"{class_names[i]} = {np.sum(image[i] == i)}")

# %%
model = Sequential([
    
])
